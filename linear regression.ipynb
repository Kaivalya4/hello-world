# %%
import numpy as np
import pandas as pd
from sklearn import svm


import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# %matplotlib inline

# %%
X = df['std'].values
Y = df['turbo'].values
mean_x = np.mean(X)
mean_y = np.mean(Y)
m = len(X)
numer = 0
denom = 0
for i in range(m):
        numer += (X[i] - mean_x) * (Y[i] - mean_y)
        denom += (X[i] - mean_x) ** 2

b1 = numer/denom
b0 = mean_y - (b1 * mean_x)
print(b1,b0)
# Out:
# -1.0 1.0

# %%
import csv
df=pd.read_csv('auto1.csv')
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# 0    3.47    2.68                9.0       111.0   5000.0       21
# 1    3.47    2.68                9.0       111.0   5000.0       21
# 2    2.68    3.47                9.0       154.0   5000.0       19
# 3    3.19    3.40               10.0       102.0   5500.0       24
# 4    3.19    3.40                8.0       115.0   5500.0       18
# ..    ...     ...                ...         ...      ...      ...
# 200  3.78    3.15                9.5       114.0   5400.0       23
# 201  3.78    3.15                8.7       160.0   5300.0       19
# 202  3.58    2.87                8.8       134.0   5500.0       18
# 203  3.01    3.40               23.0       106.0   4800.0       26
# 204  3.78    3.15                9.5       114.0   5400.0       19
#
#      highway-mpg    price  std  turbo
# 0       8.703704  13495.0    1      0
# 1       8.703704  16500.0    1      0
# 2       9.038462  16500.0    1      0
# 3       7.833333  13950.0    1      0
# 4      10.681818  17450.0    1      0
# ..           ...      ...  ...    ...
# 200     8.392857  16845.0    1      0
# 201     9.400000  19045.0    0      1
# 202    10.217391  21485.0    1      0
# 203     8.703704  22470.0    0      1
# 204     9.400000  22625.0    0      1
#
# [205 rows x 28 columns]

# %%
df.dropna(subset=['price'],axis=0,inplace= True)
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# 0    3.47    2.68                9.0       111.0   5000.0       21
# 1    3.47    2.68                9.0       111.0   5000.0       21
# 2    2.68    3.47                9.0       154.0   5000.0       19
# 3    3.19    3.40               10.0       102.0   5500.0       24
# 4    3.19    3.40                8.0       115.0   5500.0       18
# ..    ...     ...                ...         ...      ...      ...
# 200  3.78    3.15                9.5       114.0   5400.0       23
# 201  3.78    3.15                8.7       160.0   5300.0       19
# 202  3.58    2.87                8.8       134.0   5500.0       18
# 203  3.01    3.40               23.0       106.0   4800.0       26
# 204  3.78    3.15                9.5       114.0   5400.0       19
#
#      highway-mpg    price  std  turbo
# 0       8.703704  13495.0    1      0
# 1       8.703704  16500.0    1      0
# 2       9.038462  16500.0    1      0
# 3       7.833333  13950.0    1      0
# 4      10.681818  17450.0    1      0
# ..           ...      ...  ...    ...
# 200     8.392857  16845.0    1      0
# 201     9.400000  19045.0    0      1
# 202    10.217391  21485.0    1      0
# 203     8.703704  22470.0    0      1
# 204     9.400000  22625.0    0      1
#
# [201 rows x 28 columns]

# %%
max_x=np.max(X)+100
min_x=np.min(X)-100
x=np.linspace(min_x,max_x,1000)    
y= b0 + b1*x                      
plt.plot(x,y,color='#58b970',label='Regression Line')
plt.scatter(X,Y,color='#ef5423',label='Scatter Plot')
plt.xlabel('std')
plt.ylabel('turbo')
plt.legend()
plt.show()

# %%
ts=0
tr=0
for i in range(m):
    ypred=b1*X[i]+ b0
    ts+=(Y[i]-mean_y)**2
    tr+=(Y[i]-ypred)**2
r2= 1-tr/ts
print(r2)
# Out:
# 1.0

# %%
from sklearn.linear_model import LinearRegression
X=X.reshape(m,1)
lr=LinearRegression()
fit=lr.fit(X,Y)
ypred2=lr.predict(X) 
r2_score=lr.score(X,Y) 
r2_score
# Out:
# 1.0
